# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_metrics_unet = 'model/trained/seg_models/unet_metrics_1.csv'
path_metrics_u2net = 'model/trained/seg_models/u2net_metrics_1.csv'
path_metrics_deeplabv3plus_mb2 = 'model/trained/seg_models/deeplabv3plus_mb2_metrics_1.csv'
metrics_unet_df = pd.read_csv(path_metrics_unet)
metrics_deeplabv3plus_df = pd.read_csv(path_metrics_u2net)
metrics_deeplabv3plus_mb2_df = pd.read_csv(path_metrics_deeplabv3plus_mb2)
metrics_unet_df.tail() 
# metrics_deeplabv3plus_mb2_df.tail()
# Out:
#     tra_loss  tra_miou    tra_oa  val_loss  val_miou    val_oa
# 95  0.037226  0.948646  0.974186  0.041945  0.897650  0.929052
# 96  0.028738  0.931355  0.975897  0.040974  0.897720  0.928680
# 97  0.027224  0.946588  0.974776  0.040710  0.897758  0.928613
# 98  0.028455  0.947480  0.971306  0.041174  0.897363  0.927908
# 99  0.037397  0.929769  0.953019  0.041312  0.897454  0.928154

# %%
metrics_df = [metrics_unet_df, 
              metrics_deeplabv3plus_df, 
              metrics_deeplabv3plus_mb2_df]
colors = ['blue', 'orange', 'green']
labels = ['unet', 'u2net', 'deeplabv3plus_mb2']

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='val_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_title('MIoU using patch_512')
# Out:
# Text(0.5, 1.0, 'MIoU using patch_512')
