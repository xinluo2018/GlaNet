# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_metrics_unet = 'model/trained/patch_512/unet_metrics.csv'
path_metrics_deeplabv3plus = 'model/trained/patch_512/deeplabv3plus_metrics.csv'
path_metrics_deeplabv3plus_mb2 = 'model/trained/patch_512/deeplabv3plus_mobilev2_metrics.csv'
metrics_unet_df = pd.read_csv(path_metrics_unet)
metrics_deeplabv3plus_df = pd.read_csv(path_metrics_deeplabv3plus)
metrics_deeplabv3plus_mb2_df = pd.read_csv(path_metrics_deeplabv3plus_mb2)
# metrics_unet_df.tail() 
metrics_deeplabv3plus_mb2_df.tail()
# Out:
#      tra_loss    tra_oa  tra_miou  val_loss    val_oa  val_miou
# 195  0.039142  0.978335  0.939028  0.085489  0.953944  0.897143
# 196  0.043014  0.978299  0.947516  0.087076  0.950571  0.895579
# 197  0.042284  0.976752  0.947977  0.085093  0.955133  0.898146
# 198  0.042006  0.965800  0.925998  0.085710  0.951520  0.896705
# 199  0.044708  0.976636  0.949516  0.087677  0.950737  0.895844

# %%
metrics_df = [metrics_unet_df, 
              metrics_deeplabv3plus_df, 
              metrics_deeplabv3plus_mb2_df]
colors = ['blue', 'orange', 'green']
labels = ['val_miou_unet', 
          'val_miou_deeplabv3plus', 
          'val_miou_deeplabv3plus_mb2']

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='val_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_title('MIoU using patch_512')
# Out:
# Text(0.5, 1.0, 'MIoU using patch_512')
