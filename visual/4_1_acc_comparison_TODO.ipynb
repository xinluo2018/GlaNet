# %% [markdown]
# #### method comparison
# debrics-mixed glacier: s2_scene_09

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## plot bar chart of mIoU for different satellite scenes by different models
cols = ["miou_1b", "miou_2b", "miou_3b", "miou_3b_cafm"]
labels = ["Single-branch", "Double-branch", "Triple-branch", "Triple-branch + CAFM"]
colors = ["#B8B8B8", "#7EA6C4", "#4C7C9B", "#D97966"]

x = np.arange(len(acc_metrics))
w = 0.2

fig, ax = plt.subplots(figsize=(12, 3.5))

for j, (col, label, color) in enumerate(zip(cols, labels, colors)):
    ax.bar(x = x + (j - 1.5) * w,
        height = acc_metrics[col],
        width=w,
        label=label,
        color=color,
        edgecolor="white",
        linewidth=0.5)

ax.grid(axis="y", linestyle="--", linewidth=0.6, alpha=0.35)

ax.set_xticks(x)
ax.set_xticklabels([f"#{i+1}" for i in range(len(acc_metrics))])
ax.set_xlabel("Satellite Scene", fontsize=14)
ax.set_ylabel("mIoU", fontsize=14)
ax.tick_params(axis='both', labelsize=12)
ax.spines[["top", "right"]].set_visible(False)
ax.spines[["left", "bottom"]].set_linewidth(0.8)

ax.legend(
    ncol=4,
    frameon=False,
    loc="lower center",
    fontsize=12,
    bbox_to_anchor=(0.5, 1.01))

ax.set_ylim(0.85, 0.99)
ax.set_yticks(np.arange(0.85, 0.99, 0.05))
plt.tight_layout()
plt.show()
