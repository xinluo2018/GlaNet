# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_metrics_u2net = 'model/trained/u2net_att_512/u2net_att_metrics_1.csv'
path_metrics_u2net_dem_adjust = 'model/trained/u2net_att_512/u2net_att_metrics_dem_adjust_1.csv'

# %%
metrics_unet_df = pd.read_csv(path_metrics_u2net)
metrics_unet_dem_adjust_df = pd.read_csv(path_metrics_u2net_dem_adjust)
metrics_unet_df.tail()
metrics_unet_dem_adjust_df.tail()
# Out:
#     tra_loss  tra_miou    tra_oa  val_loss  val_miou    val_oa
# 95  0.011439  0.942717  0.976304  0.014802  0.896118  0.937187
# 96  0.012321  0.952103  0.979951  0.014593  0.896195  0.937733
# 97  0.010652  0.929054  0.955939  0.014648  0.896217  0.937700
# 98  0.009205  0.965535  0.981891  0.014626  0.896272  0.937849
# 99  0.009555  0.962905  0.981380  0.015030  0.894517  0.935566

# %%
metrics_unet_df = [metrics_unet_df, metrics_unet_dem_adjust_df]
colors = ['blue', 'orange']
labels = ['without_dem_adjust', 'with_dem_adjust']

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_unet_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='val_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_title('MIoU using dem_adjust method')
# Out:
# Text(0.5, 1.0, 'MIoU using dem_adjust method')
