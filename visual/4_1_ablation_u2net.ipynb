# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_metrics_unet = 'model/trained/unet_512/unet_metrics_1.csv'
path_metrics_u2net = 'model/trained/u2net_512/u2net_metrics_1.csv'

# %%
metrics_unet_df = pd.read_csv(path_metrics_unet)
metrics_u2net_df = pd.read_csv(path_metrics_u2net)
metrics_unet_df.tail()
metrics_u2net_df.tail(10)
# Out:
#     tra_loss  tra_miou    tra_oa  val_loss  val_miou    val_oa
# 90  0.010176  0.943799  0.975030  0.014421  0.892478  0.933733
# 91  0.009091  0.947601  0.975797  0.014665  0.893822  0.934123
# 92  0.009610  0.948660  0.971499  0.014803  0.894181  0.933482
# 93  0.010457  0.945091  0.969065  0.014586  0.893747  0.933870
# 94  0.011471  0.926136  0.963515  0.014675  0.894161  0.934017
# 95  0.007828  0.953765  0.980623  0.015085  0.895733  0.933523
# 96  0.007906  0.957734  0.978379  0.014581  0.895012  0.934319
# 97  0.010060  0.950684  0.979392  0.014346  0.893503  0.934845
# 98  0.008685  0.939067  0.974744  0.014417  0.892557  0.934454
# 99  0.010021  0.931683  0.961184  0.014441  0.892064  0.934111

# %%
metrics_models_df = [metrics_unet_df, metrics_u2net_df]
colors = ['blue', 'orange']
labels = ['unet', 'u2net']

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='val_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_title('MIoU using dem_adjust method')
# Out:
# Text(0.5, 1.0, 'MIoU using dem_adjust method')

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='tra_loss', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')
