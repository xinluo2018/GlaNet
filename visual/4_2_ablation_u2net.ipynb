# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_metrics_unet = 'model/trained/patch_512/unet_metrics_1.csv'
path_metrics_u2net = 'model/trained/u2net_512/u2net_metrics_1.csv'

# %%
metrics_unet_df = pd.read_csv(path_metrics_unet)
metrics_u2net_df = pd.read_csv(path_metrics_u2net)
metrics_unet_df.tail()
metrics_u2net_df.tail(10)
# Out:
#      tra_loss  tra_miou    tra_oa  val_loss  val_miou    val_oa
# 91   0.010398  0.953493  0.975621  0.017968  0.876935  0.934624
# 92   0.011255  0.950106  0.977402  0.018219  0.884514  0.937620
# 93   0.011229  0.934107  0.959511  0.017599  0.879128  0.935231
# 94   0.011701  0.936469  0.966747  0.020042  0.863020  0.931914
# 95   0.010606  0.917623  0.944187  0.018949  0.868494  0.932037
# 96   0.011279  0.935723  0.968190  0.017811  0.875214  0.934470
# 97   0.007928  0.966160  0.981847  0.017394  0.878027  0.934670
# 98   0.009691  0.960212  0.981395  0.017634  0.876160  0.935081
# 99   0.009537  0.958785  0.979276  0.018208  0.873790  0.934501
# 100  0.011524  0.960858  0.980384  0.018357  0.881061  0.936791

# %%
metrics_models_df = [metrics_unet_df, metrics_u2net_df]
colors = ['blue', 'orange']
labels = ['unet', 'u2net']

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='val_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_title('MIoU using dem_adjust method')
# Out:
# Text(0.5, 1.0, 'MIoU using dem_adjust method')

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='tra_loss', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')
