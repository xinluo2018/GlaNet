# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_metrics_unet = 'model/trained/patch_512/unet_metrics_2.csv'
path_metrics_u2net = 'model/trained/u2net_512/u2net_metrics.csv'

# %%
metrics_unet_df = pd.read_csv(path_metrics_unet)
metrics_u2net_df = pd.read_csv(path_metrics_u2net)
metrics_unet_df.tail()
metrics_u2net_df.tail(10)
# Out:
#      tra_loss  tra_miou    tra_oa  val_loss  val_miou    val_oa
# 190  0.013788  0.942653  0.967136  0.013428  0.897878  0.937011
# 191  0.008859  0.942224  0.983382  0.013397  0.896231  0.936815
# 192  0.010534  0.948381  0.977362  0.013534  0.895163  0.937192
# 193  0.010006  0.959098  0.983069  0.013465  0.895722  0.936893
# 194  0.009853  0.937483  0.958914  0.013386  0.896651  0.935931
# 195  0.009925  0.950633  0.977219  0.013139  0.898670  0.936349
# 196  0.009881  0.939818  0.970816  0.013130  0.898319  0.938262
# 197  0.010508  0.917493  0.946037  0.013419  0.896378  0.938429
# 198  0.013335  0.932283  0.971080  0.013386  0.900360  0.935621
# 199  0.009415  0.953009  0.973086  0.017703  0.880552  0.918789

# %%
metrics_models_df = [metrics_unet_df, metrics_u2net_df]
colors = ['blue', 'orange']
labels = ['unet', 'u2net']

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='val_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_title('MIoU using dem_adjust method')
# Out:
# Text(0.5, 1.0, 'MIoU using dem_adjust method')

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='tra_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')
