# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_metrics_unet = 'model/trained/u2net_512/u2net_metrics_1.csv'
path_metrics_unet_att = 'model/trained/u2net_att_512/u2net_att_metrics_1.csv'

# %%
metrics_unet_df = pd.read_csv(path_metrics_unet)
metrics_unet_att_df = pd.read_csv(path_metrics_unet_att)
metrics_unet_df.tail()
metrics_unet_att_df.tail()
# Out:
#     tra_loss  tra_miou    tra_oa  val_loss  val_miou    val_oa
# 95  0.008307  0.952241  0.977527  0.014137  0.893706  0.936814
# 96  0.007705  0.953185  0.978040  0.014155  0.893492  0.936340
# 97  0.008452  0.949773  0.977981  0.014195  0.893241  0.935618
# 98  0.009387  0.950348  0.979249  0.014249  0.893216  0.936037
# 99  0.008151  0.956345  0.978109  0.014315  0.893016  0.936227

# %%
metrics_models_df = [metrics_unet_df, metrics_unet_att_df]
colors = ['blue', 'orange']
labels = ['unet', 'unet_att']

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='val_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_title('validation MIoU using unet method') 
ax.set_ylim(0.7, 0.91)
# Out:
# (0.7, 0.91)

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='tra_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_title('training miou using unet method')
# Out:
# Text(0.5, 1.0, 'training miou using unet method')

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='tra_loss', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, metric_df in enumerate(metrics_models_df):
    sns.lineplot(data=metric_df, 
                x=metric_df.index, 
                y='tra_oa', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')
