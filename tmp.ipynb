# %%
from pyrsimg import raster2vec  
from glob import glob

# %%
paths = glob('data/result/ablation_data/u3net_timm_remove_rgb/*.tif') 
paths
# Out:
# ['data/result/ablation_data/u3net_timm_remove_rgb/l7_scene_13_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/s2_scene_04_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l7_scene_03_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l8_scene_05_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l9_scene_07_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l5_scene_01_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l8_scene_10_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l5_scene_11_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l9_scene_12_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l7_scene_08_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l5_scene_06_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/l9_scene_02_pred.tif',
#  'data/result/ablation_data/u3net_timm_remove_rgb/s2_scene_09_pred.tif']

# %%
for path in paths:
     path_save = path.replace('.tif', '_vec.gpkg')
     dn_values = [1]
     print(path_save)      
     raster2vec(path_raster=path, path_save=path_save, dn_values=dn_values)
# Out:
# data/result/ablation_data/u3net_timm_remove_rgb/l7_scene_13_pred_vec.gpkg
# Vector saved to data/result/ablation_data/u3net_timm_remove_rgb/l7_scene_13_pred_vec.gpkg, Feature count: 155
# data/result/ablation_data/u3net_timm_remove_rgb/s2_scene_04_pred_vec.gpkg
# Vector saved to data/result/ablation_data/u3net_timm_remove_rgb/s2_scene_04_pred_vec.gpkg, Feature count: 102
# data/result/ablation_data/u3net_timm_remove_rgb/l7_scene_03_pred_vec.gpkg
# Vector saved to data/result/ablation_data/u3net_timm_remove_rgb/l7_scene_03_pred_vec.gpkg, Feature count: 267
# data/result/ablation_data/u3net_timm_remove_rgb/l8_scene_05_pred_vec.gpkg
# Vector saved to data/result/ablation_data/u3net_timm_remove_rgb/l8_scene_05_pred_vec.gpkg, Feature count: 382
# data/result/ablation_data/u3net_timm_remove_rgb/l9_scene_07_pred_vec.gpkg
# Vector saved to data/result/ablation_data/u3net_timm_remove_rgb/l9_scene_07_pred_vec.gpkg, Feature count: 1299
# ...
