# %%
import torch
from glob import glob
from model import unet
from utils.imgShow import imsShow
from utils.dataloader import PatchPathSet
import rasterio as rio 
from rasterio.warp import transform_bounds

# %%
path_dem = 'data/dset/dem/l5_scene_01_dem_nor.tif'
dem_rio = rio.open(path_dem)

# %%
dem_rio.crs.to_epsg()
# Out:
# 32618

# %%
dem_rio.bounds
# Out:
# BoundingBox(left=608640.0, bottom=-5125020.0, right=660060.0, top=-5073900.0)

# %%
wgs84_bounds = transform_bounds(src_crs=dem_rio.crs, 
                                dst_crs='EPSG:4326', 
                                left=dem_rio.bounds.left, 
                                bottom=dem_rio.bounds.bottom, 
                                right=dem_rio.bounds.right, 
                                top=dem_rio.bounds.top) 

lat_deg = (wgs84_bounds[1] + wgs84_bounds[3]) / 2
lat_deg
# Out:
# -46.03507861298661
