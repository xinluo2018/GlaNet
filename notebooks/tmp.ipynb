# %%
import torch
import torch.nn as nn

# %%
class LatitudinalCorrection(nn.Module):
    def __init__(self, init_alpha=0.3):
        super().__init__()
        self.alpha = nn.Parameter(torch.tensor(init_alpha))
        
    def forward(self, dem, latitude):
        latitude = latitude.view(-1,1,1,1)  # reshape for broadcasting
        lat_weight = (90 - torch.abs(latitude)) / 90  ## normalize to [0,1]      
        dem_adjusted = dem * (1 + self.alpha * lat_weight)        
        return dem_adjusted

lat_correction = LatitudinalCorrection()

dem = torch.randn(4,1,256,256)*1000  # dummy DEM image batch
lat = torch.tensor([30.0,60.0,15.0,75.0])  # dummy latitude batch
dem_adjusted = lat_correction(dem, lat)

# %%
# Out:
# torch.float32
