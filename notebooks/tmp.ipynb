# %%
import torch
from glob import glob
from model import unet
from utils.imgShow import imsShow
from utils.dataloader import PatchPathSet
import rasterio as rio 
from rasterio.warp import transform_bounds

# %%
# 获取当前默认设备
if torch.cuda.is_available():
    current_device = torch.cuda.current_device()
    print(f"当前设备: cuda:{current_device}")
# Out:
# 当前设备: cuda:0

# %%
import torch

# %%
tensor_1 = torch.randn(1, 3, 256, 256, requires_grad=True) 
tensor_2 = torch.randn(1, 3, 256, 256, requires_grad=True)
result = (tensor_1 + tensor_2).mean()
print(result)
# Out:
# tensor(-0.0010, grad_fn=<MeanBackward0>)

# %%
tensor_1.grad.shape
# Out:
# torch.Size([1, 3, 256, 256])
