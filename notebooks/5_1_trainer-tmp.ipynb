# %% [markdown]
# ### Deep learning model training.

# %%
import time
import torch
import random
import pandas as pd
import torch.nn as nn
from glob import glob
from model import u2net 
import geopandas as gpd 
from notebooks import config
import torch.nn.functional as F
from utils.imgShow import imsShow
from utils.utils import read_scenes
from utils.metrics import oa_binary, miou_binary
from utils.dataloader import SceneArraySet, PatchPathSet, PatchPathSet_2
from model import unet, deeplabv3plus, deeplabv3plus_mobilev2, u2net
from model import u2net_dem_adj

# %%
patch_size = 512  ## patch size setting
patch_resize = None  ## patch resize setting
### traset
paths_scene_tra, paths_truth_tra = config.paths_scene_tra, config.paths_truth_tra
# paths_dem_tra = config.paths_dem_tra
paths_dem_tra = config.paths_dem_adjust_tra
print(f'train scenes: {len(paths_scene_tra)}')
### valset
paths_valset = sorted(glob(f'data/dset/valset/patch_{patch_size}/*'))  ## for model prediction 
# paths_valset = sorted(glob(f'data/dset/valset/patch_{patch_size}_dem_adjust/*'))
print(f'vali patch {patch_size}: {len(paths_valset)}')
# Out:
# train scenes: 48
# vali patch 512: 293

# %% [markdown]
# ### dataset loading

# %%
scenes_arr, truths_arr, scenes_lat = read_scenes(paths_scene_tra, 
                                     paths_truth_tra, 
                                     paths_dem_tra)

# %%
## Create dataset instances
tra_data = SceneArraySet(scenes_arr=scenes_arr, 
                         truths_arr=truths_arr, 
                         scenes_lat=scenes_lat,
                         patch_size=patch_size,
                         patch_resize=patch_resize)
val_data = PatchPathSet_2(paths_valset=paths_valset, 
                          patch_resize=patch_resize)
tra_loader = torch.utils.data.DataLoader(tra_data, 
                                         batch_size=4, 
                                         shuffle=True, 
                                         num_workers=5)
val_loader = torch.utils.data.DataLoader(val_data, 
                                         batch_size=4, 
                                         num_workers=5)

# %% [markdown]
# #### Model training

# %%
### check model
# model = unet(num_bands=7)
# model = u2net(num_bands_b1=6, num_bands_b2=1)
model = u2net_dem_adj(num_bands_b1=6, num_bands_b2=1)
# model = u2net_att_2(num_bands_b1=6, num_bands_b2=1)
# model = deeplabv3plus(num_bands=7)
# model = deeplabv3plus_mobilev2(num_bands=7)

# %%
input_tensor = torch.randn(2, 7, 512, 512)  
latitude = torch.randn(2)  # batch size of 2, 1 latitude value per sample
# output = model(input_tensor) 
output = model(input_tensor, latitude) 
print(output.shape)
# Out:
# torch.Size([2, 1, 512, 512])

# %%
### create loss and optimizer
loss_bce = nn.BCELoss()
loss_mse = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)  
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, \
                                      mode='min', factor=0.6, patience=20)

# %%
'''------train step------'''
def train_step(model, loss_fn, optimizer, x, y, lat, lat_in=True):
    optimizer.zero_grad()
    if lat_in:
        pred = model(x, lat)
    else:
        pred = model(x)
    loss = loss_fn(pred, y.float())
    loss.backward()
    optimizer.step()
    miou = miou_binary(pred=pred, truth=y, device=x.device)
    oa = oa_binary(pred=pred, truth=y, device=x.device)
    return loss, miou, oa

'''------validation step------'''
def val_step(model, loss_fn, x, y, lat, patch_size,
              patch_resize, lat_in=True):
    model.eval()
    with torch.no_grad():
        if lat_in:
            pred = model(x.float(), lat)
        else:
            pred = model(x.float())
        if patch_size > 256:
            if patch_resize == 256:
                pred = F.interpolate(pred, 
                                size=(patch_size, patch_size), 
                                mode='bilinear',
                                align_corners=True)
            crop_start = (patch_size-256)//2
            pred = pred[:, :, crop_start:crop_start+256, crop_start:crop_start+256]  ## crop to inner 256x256 patch
        loss = loss_fn(pred, y.float())
    miou = miou_binary(pred=pred, truth=y, device=x.device)
    oa = oa_binary(pred=pred, truth=y, device=x.device)
    return loss, miou, oa

'''------train loops------'''
def train_loops(model, loss_fn, 
                    optimizer, 
                    tra_loader, val_loader,                     
                    epoches, 
                    device, patch_size, patch_resize,
                    lat_in=True,
                    lr_scheduler=None):
    tra_loss_loops, tra_miou_loops, tra_oa_loops = [], [], []
    val_loss_loops, val_miou_loops, val_oa_loops = [], [], []
    model = model.to(device)
    size_tra_loader = len(tra_loader)
    size_val_loader = len(val_loader)
    for epoch in range(epoches):
        start = time.time()
        tra_loss, val_loss = 0, 0
        tra_miou, val_miou = 0, 0
        tra_oa, val_oa = 0, 0
        '''-----train the model-----'''
        for x_batch, y_batch, lat_batch in tra_loader:
            x_batch, y_batch, lat_batch = x_batch.to(device), y_batch.to(device), lat_batch.to(device)
            loss, miou, oa = train_step(model=model, loss_fn=loss_fn, 
                                            optimizer=optimizer, 
                                            x=x_batch, 
                                            y=y_batch, 
                                            lat=lat_batch,
                                            lat_in=lat_in)
            tra_loss += loss.item()
            tra_miou += miou.item()
            tra_oa += oa.item()
        if lr_scheduler:
          lr_scheduler.step(tra_loss)    # if using ReduceLROnPlateau
        '''----- validation the model: time consuming -----'''
        if epoch %3 != 0: 
            tra_loss = tra_loss/size_tra_loader
            tra_miou = tra_miou/size_tra_loader
            tra_oa = tra_oa/size_tra_loader
            print(f'Ep{epoch+1}: tra-> Loss:{tra_loss:.3f},Oa:{tra_oa:.3f},Miou:{tra_miou:.3f}, \
                                time:{time.time()-start:.1f}s')
            continue
        for x_batch, y_batch, lat_batch in val_loader:
            x_batch, y_batch, lat_batch = x_batch.to(device), y_batch.to(device), lat_batch.to(device)
            loss, miou, oa = val_step(model=model, 
                                        loss_fn=loss_fn, 
                                        x=x_batch, 
                                        y=y_batch, 
                                        lat=lat_batch,
                                        patch_size=patch_size,
                                        lat_in=lat_in, 
                                        patch_resize=patch_resize)
            val_loss += loss.item()
            val_miou += miou.item()
            val_oa += oa.item()
        ## Accuracy
        tra_loss = tra_loss/size_tra_loader
        val_loss = val_loss/size_val_loader
        tra_miou = tra_miou/size_tra_loader
        val_miou = val_miou/size_val_loader
        tra_oa = tra_oa/size_tra_loader
        val_oa = val_oa/size_val_loader
        tra_loss_loops.append(tra_loss); tra_miou_loops.append(tra_miou); tra_oa_loops.append(tra_oa)
        val_loss_loops.append(val_loss); val_miou_loops.append(val_miou); val_oa_loops.append(val_oa)
        print(f'Ep{epoch}: tra-> Loss:{tra_loss:.3f},Oa:{tra_oa:.3f},Miou:{tra_miou:.3f}, '
                f'val-> Loss:{val_loss:.3f},Oa:{val_oa:.3f}, Miou:{val_miou:.3f},time:{time.time()-start:.1f}s')
        ## show the result
        if (epoch+1)%20 == 0:
            model.eval()
            sam_index = random.randrange(len(val_data))
            patch, truth, lat = val_data[sam_index]
            patch, truth = patch.float().unsqueeze(0).to(device), truth.to(device)
            lat = torch.tensor([lat]).unsqueeze(0).to(device)
            if lat_in:
                pred = model(patch, lat)
            else:
                pred = model(patch)
            if patch_size > 256:
                while patch_resize == 256:
                    patch = F.interpolate(patch, 
                                    size=(patch_size, patch_size), 
                                    mode='bilinear',
                                    align_corners=True)
                    pred = F.interpolate(pred, 
                                    size=(patch_size, patch_size), 
                                    mode='bilinear',
                                    align_corners=True)
                    break
                crop_start = (patch_size-256)//2                
                patch_val = patch[:, :, crop_start:crop_start+256, crop_start:crop_start+256]  ## crop to match the size
                pred_val = pred[:, :, crop_start:crop_start+256, crop_start:crop_start+256]  ## crop to match the size
            else:
                patch_val = patch
                pred_val = pred
            ## convert to numpy and plot
            patch = patch[0].to('cpu').detach().numpy().transpose(1,2,0)
            pdem = patch[:,:, -1]
            patch_val = patch_val[0].to('cpu').detach().numpy().transpose(1,2,0)
            pred_val = pred_val[0].to('cpu').detach().numpy()
            truth_val = truth.to('cpu').detach().numpy()
            imsShow([patch, pdem, patch_val, pred_val, truth_val], 
                    clip_list = (2,2,2,0,0),
                    img_name_list=['input_patch', 'pdem', 'patch_val', 'pred_val', 'truth_val'],                     
                    figsize=(15, 3))
    metrics = {'tra_loss':tra_loss_loops, 'tra_miou':tra_miou_loops, 'tra_oa': tra_oa_loops, 
                'val_loss': val_loss_loops, 'val_miou': val_miou_loops, 'val_oa': val_oa_loops}
    return metrics

# %%
device = torch.device('cuda:0') 
metrics = train_loops(model=model, 
                epoches=300,  
                loss_fn=loss_mse,  
                optimizer=optimizer,  
                tra_loader=tra_loader,  
                val_loader=val_loader,  
                lat_in = True,
                patch_size=patch_size,  
                patch_resize=None,  
                lr_scheduler=lr_scheduler,  
                device=device)
# Out:
# Ep0: tra-> Loss:0.120,Oa:0.775,Miou:0.680, val-> Loss:0.156,Oa:0.820, Miou:0.689,time:3.1s
# Ep2: tra-> Loss:0.055,Oa:0.938,Miou:0.846,                                 time:1.5s
# Ep3: tra-> Loss:0.047,Oa:0.916,Miou:0.848,                                 time:1.6s
# Ep3: tra-> Loss:0.036,Oa:0.902,Miou:0.830, val-> Loss:0.064,Oa:0.861, Miou:0.764,time:3.0s
# Ep5: tra-> Loss:0.050,Oa:0.923,Miou:0.862,                                 time:1.6s
# Ep6: tra-> Loss:0.018,Oa:0.947,Miou:0.891,                                 time:1.5s
# Ep6: tra-> Loss:0.026,Oa:0.928,Miou:0.890, val-> Loss:0.045,Oa:0.883, Miou:0.798,time:2.9s
# Ep8: tra-> Loss:0.017,Oa:0.948,Miou:0.902,                                 time:1.4s
# Ep9: tra-> Loss:0.028,Oa:0.919,Miou:0.872,                                 time:1.5s
# Ep9: tra-> Loss:0.023,Oa:0.947,Miou:0.921, val-> Loss:0.045,Oa:0.877, Miou:0.785,time:3.0s
# Ep11: tra-> Loss:0.025,Oa:0.957,Miou:0.880,                                 time:1.5s
# Ep12: tra-> Loss:0.029,Oa:0.931,Miou:0.894,                                 time:1.5s
# Ep12: tra-> Loss:0.028,Oa:0.960,Miou:0.925, val-> Loss:0.046,Oa:0.889, Miou:0.804,time:3.0s
# Ep14: tra-> Loss:0.021,Oa:0.938,Miou:0.899,                                 time:1.5s
# Ep15: tra-> Loss:0.015,Oa:0.951,Miou:0.910,                                 time:1.4s
# Ep15: tra-> Loss:0.021,Oa:0.954,Miou:0.922, val-> Loss:0.039,Oa:0.893, Miou:0.810,time:3.0s
# Ep17: tra-> Loss:0.024,Oa:0.934,Miou:0.886,                                 time:1.5s
# Ep18: tra-> Loss:0.023,Oa:0.940,Miou:0.900,                                 time:1.6s
# Ep18: tra-> Loss:0.020,Oa:0.937,Miou:0.904, val-> Loss:0.046,Oa:0.882, Miou:0.811,time:3.0s
# Ep20: tra-> Loss:0.022,Oa:0.937,Miou:0.894,                                 time:1.7s
# Ep21: tra-> Loss:0.031,Oa:0.915,Miou:0.845,                                 time:1.5s
# Ep21: tra-> Loss:0.019,Oa:0.952,Miou:0.914, val-> Loss:0.041,Oa:0.887, Miou:0.811,time:3.2s
# Ep23: tra-> Loss:0.023,Oa:0.939,Miou:0.906,                                 time:1.5s
# Ep24: tra-> Loss:0.021,Oa:0.948,Miou:0.889,                                 time:1.5s
# Ep24: tra-> Loss:0.017,Oa:0.950,Miou:0.914, val-> Loss:0.028,Oa:0.904, Miou:0.840,time:3.2s
# Ep26: tra-> Loss:0.024,Oa:0.944,Miou:0.908,                                 time:1.5s
# Ep27: tra-> Loss:0.015,Oa:0.967,Miou:0.902,                                 time:1.7s
# Ep27: tra-> Loss:0.024,Oa:0.946,Miou:0.909, val-> Loss:0.023,Oa:0.927, Miou:0.850,time:3.3s
# Ep29: tra-> Loss:0.015,Oa:0.975,Miou:0.951,                                 time:1.6s
# Ep30: tra-> Loss:0.040,Oa:0.946,Miou:0.894,                                 time:1.6s
# Ep30: tra-> Loss:0.027,Oa:0.948,Miou:0.911, val-> Loss:0.038,Oa:0.897, Miou:0.832,time:3.0s
# Ep32: tra-> Loss:0.026,Oa:0.900,Miou:0.843,                                 time:1.4s
# Ep33: tra-> Loss:0.018,Oa:0.966,Miou:0.927,                                 time:1.6s
# Ep33: tra-> Loss:0.025,Oa:0.956,Miou:0.906, val-> Loss:0.031,Oa:0.896, Miou:0.834,time:3.0s
# Ep35: tra-> Loss:0.019,Oa:0.959,Miou:0.926,                                 time:1.7s
# Ep36: tra-> Loss:0.018,Oa:0.960,Miou:0.937,                                 time:1.5s
# Ep36: tra-> Loss:0.020,Oa:0.960,Miou:0.913, val-> Loss:0.029,Oa:0.894, Miou:0.843,time:3.0s
# Ep38: tra-> Loss:0.021,Oa:0.914,Miou:0.877,                                 time:1.6s
# Ep39: tra-> Loss:0.014,Oa:0.929,Miou:0.897,                                 time:1.5s
# Ep39: tra-> Loss:0.016,Oa:0.962,Miou:0.931, val-> Loss:0.019,Oa:0.928, Miou:0.875,time:3.1s
# Ep41: tra-> Loss:0.015,Oa:0.969,Miou:0.902,                                 time:1.5s
# Ep42: tra-> Loss:0.016,Oa:0.967,Miou:0.925,                                 time:1.6s
# Ep42: tra-> Loss:0.014,Oa:0.972,Miou:0.941, val-> Loss:0.017,Oa:0.930, Miou:0.876,time:3.3s
# Ep44: tra-> Loss:0.015,Oa:0.972,Miou:0.944,                                 time:1.5s
# Ep45: tra-> Loss:0.014,Oa:0.963,Miou:0.927,                                 time:1.6s
# Ep45: tra-> Loss:0.012,Oa:0.967,Miou:0.922, val-> Loss:0.018,Oa:0.924, Miou:0.880,time:3.2s
# Ep47: tra-> Loss:0.015,Oa:0.971,Miou:0.922,                                 time:1.6s
# Ep48: tra-> Loss:0.016,Oa:0.965,Miou:0.928,                                 time:1.7s
# Ep48: tra-> Loss:0.016,Oa:0.959,Miou:0.923, val-> Loss:0.016,Oa:0.936, Miou:0.879,time:3.2s
# Ep50: tra-> Loss:0.019,Oa:0.972,Miou:0.929,                                 time:1.7s
# Ep51: tra-> Loss:0.012,Oa:0.970,Miou:0.940,                                 time:1.5s
# Ep51: tra-> Loss:0.014,Oa:0.973,Miou:0.940, val-> Loss:0.016,Oa:0.934, Miou:0.888,time:3.2s
# Ep53: tra-> Loss:0.016,Oa:0.956,Miou:0.923,                                 time:1.6s
# Ep54: tra-> Loss:0.025,Oa:0.966,Miou:0.914,                                 time:1.6s
# Ep54: tra-> Loss:0.011,Oa:0.959,Miou:0.940, val-> Loss:0.019,Oa:0.925, Miou:0.879,time:3.3s
# Ep56: tra-> Loss:0.016,Oa:0.957,Miou:0.920,                                 time:1.5s
# Ep57: tra-> Loss:0.016,Oa:0.965,Miou:0.932,                                 time:1.6s
# Ep57: tra-> Loss:0.011,Oa:0.977,Miou:0.948, val-> Loss:0.015,Oa:0.931, Miou:0.884,time:3.1s
# Ep59: tra-> Loss:0.012,Oa:0.968,Miou:0.940,                                 time:1.6s
# Ep60: tra-> Loss:0.012,Oa:0.972,Miou:0.942,                                 time:1.5s
# Ep60: tra-> Loss:0.018,Oa:0.970,Miou:0.928, val-> Loss:0.020,Oa:0.916, Miou:0.870,time:3.1s
# Ep62: tra-> Loss:0.017,Oa:0.962,Miou:0.907,                                 time:1.5s
# Ep63: tra-> Loss:0.011,Oa:0.973,Miou:0.941,                                 time:1.5s
# Ep63: tra-> Loss:0.015,Oa:0.966,Miou:0.939, val-> Loss:0.014,Oa:0.935, Miou:0.887,time:3.0s
# Ep65: tra-> Loss:0.027,Oa:0.962,Miou:0.882,                                 time:1.5s
# Ep66: tra-> Loss:0.015,Oa:0.976,Miou:0.931,                                 time:1.5s
# Ep66: tra-> Loss:0.015,Oa:0.974,Miou:0.948, val-> Loss:0.013,Oa:0.936, Miou:0.897,time:3.1s
# Ep68: tra-> Loss:0.008,Oa:0.965,Miou:0.924,                                 time:1.6s
# Ep69: tra-> Loss:0.012,Oa:0.974,Miou:0.953,                                 time:1.5s
# Ep69: tra-> Loss:0.013,Oa:0.981,Miou:0.948, val-> Loss:0.014,Oa:0.936, Miou:0.892,time:3.0s
# Ep71: tra-> Loss:0.011,Oa:0.952,Miou:0.932,                                 time:1.4s
# Ep72: tra-> Loss:0.012,Oa:0.983,Miou:0.961,                                 time:1.6s
# Ep72: tra-> Loss:0.016,Oa:0.964,Miou:0.923, val-> Loss:0.024,Oa:0.909, Miou:0.859,time:3.0s
# Ep74: tra-> Loss:0.016,Oa:0.973,Miou:0.943,                                 time:1.6s
# Ep75: tra-> Loss:0.010,Oa:0.985,Miou:0.962,                                 time:1.5s
# Ep75: tra-> Loss:0.013,Oa:0.974,Miou:0.934, val-> Loss:0.019,Oa:0.932, Miou:0.872,time:3.1s
# Ep77: tra-> Loss:0.011,Oa:0.972,Miou:0.951,                                 time:1.5s
# Ep78: tra-> Loss:0.009,Oa:0.985,Miou:0.968,                                 time:1.4s
# Ep78: tra-> Loss:0.013,Oa:0.973,Miou:0.949, val-> Loss:0.015,Oa:0.934, Miou:0.884,time:3.0s
# Ep80: tra-> Loss:0.013,Oa:0.963,Miou:0.927,                                 time:1.6s
# Ep81: tra-> Loss:0.011,Oa:0.981,Miou:0.942,                                 time:1.5s
# Ep81: tra-> Loss:0.012,Oa:0.942,Miou:0.922, val-> Loss:0.014,Oa:0.934, Miou:0.891,time:3.1s
# Ep83: tra-> Loss:0.012,Oa:0.960,Miou:0.930,                                 time:1.5s
# Ep84: tra-> Loss:0.010,Oa:0.980,Miou:0.958,                                 time:1.5s
# Ep84: tra-> Loss:0.011,Oa:0.972,Miou:0.931, val-> Loss:0.014,Oa:0.936, Miou:0.892,time:3.0s
# Ep86: tra-> Loss:0.010,Oa:0.980,Miou:0.960,                                 time:1.4s
# Ep87: tra-> Loss:0.008,Oa:0.971,Miou:0.944,                                 time:1.5s
# Ep87: tra-> Loss:0.015,Oa:0.967,Miou:0.939, val-> Loss:0.014,Oa:0.941, Miou:0.892,time:3.1s
# Ep89: tra-> Loss:0.014,Oa:0.938,Miou:0.905,                                 time:1.5s
# Ep90: tra-> Loss:0.011,Oa:0.980,Miou:0.950,                                 time:1.5s
# Ep90: tra-> Loss:0.010,Oa:0.975,Miou:0.948, val-> Loss:0.014,Oa:0.939, Miou:0.892,time:3.0s
# Ep92: tra-> Loss:0.012,Oa:0.961,Miou:0.932,                                 time:1.6s
# Ep93: tra-> Loss:0.011,Oa:0.963,Miou:0.933,                                 time:1.5s
# Ep93: tra-> Loss:0.022,Oa:0.969,Miou:0.931, val-> Loss:0.046,Oa:0.889, Miou:0.830,time:3.0s
# Ep95: tra-> Loss:0.042,Oa:0.876,Miou:0.838,                                 time:1.5s
# Ep96: tra-> Loss:0.023,Oa:0.918,Miou:0.893,                                 time:1.7s
# Ep96: tra-> Loss:0.020,Oa:0.952,Miou:0.908, val-> Loss:0.040,Oa:0.885, Miou:0.801,time:3.2s
# Ep98: tra-> Loss:0.018,Oa:0.964,Miou:0.917,                                 time:1.6s
# Ep99: tra-> Loss:0.019,Oa:0.959,Miou:0.917,                                 time:1.7s
# Ep99: tra-> Loss:0.019,Oa:0.949,Miou:0.915, val-> Loss:0.033,Oa:0.894, Miou:0.832,time:3.2s
# Ep101: tra-> Loss:0.018,Oa:0.968,Miou:0.935,                                 time:1.6s
# Ep102: tra-> Loss:0.017,Oa:0.924,Miou:0.900,                                 time:1.6s
# Ep102: tra-> Loss:0.016,Oa:0.969,Miou:0.940, val-> Loss:0.026,Oa:0.902, Miou:0.841,time:3.1s
# Ep104: tra-> Loss:0.013,Oa:0.970,Miou:0.940,                                 time:1.5s
# Ep105: tra-> Loss:0.014,Oa:0.960,Miou:0.902,                                 time:1.5s
# Ep105: tra-> Loss:0.014,Oa:0.965,Miou:0.940, val-> Loss:0.023,Oa:0.920, Miou:0.852,time:3.2s
# Ep107: tra-> Loss:0.013,Oa:0.978,Miou:0.939,                                 time:1.4s
# Ep108: tra-> Loss:0.016,Oa:0.964,Miou:0.916,                                 time:1.5s
# Ep108: tra-> Loss:0.019,Oa:0.959,Miou:0.932, val-> Loss:0.018,Oa:0.927, Miou:0.892,time:3.1s
# Ep110: tra-> Loss:0.013,Oa:0.972,Miou:0.932,                                 time:1.9s
# Ep111: tra-> Loss:0.014,Oa:0.977,Miou:0.928,                                 time:1.5s
# Ep111: tra-> Loss:0.013,Oa:0.953,Miou:0.925, val-> Loss:0.016,Oa:0.930, Miou:0.880,time:3.1s
# Ep113: tra-> Loss:0.009,Oa:0.981,Miou:0.958,                                 time:1.5s
# Ep114: tra-> Loss:0.015,Oa:0.959,Miou:0.934,                                 time:1.4s
# Ep114: tra-> Loss:0.015,Oa:0.970,Miou:0.937, val-> Loss:0.015,Oa:0.934, Miou:0.883,time:3.2s
# Ep116: tra-> Loss:0.014,Oa:0.975,Miou:0.922,                                 time:1.6s
# Ep117: tra-> Loss:0.010,Oa:0.971,Miou:0.934,                                 time:1.5s
# Ep117: tra-> Loss:0.014,Oa:0.976,Miou:0.947, val-> Loss:0.017,Oa:0.932, Miou:0.875,time:3.2s
# Ep119: tra-> Loss:0.010,Oa:0.951,Miou:0.928,                                 time:1.8s
# Ep120: tra-> Loss:0.010,Oa:0.975,Miou:0.946,                                 time:1.5s
# Ep120: tra-> Loss:0.013,Oa:0.974,Miou:0.943, val-> Loss:0.014,Oa:0.935, Miou:0.889,time:3.0s
# Ep122: tra-> Loss:0.012,Oa:0.975,Miou:0.940,                                 time:1.5s
# Ep123: tra-> Loss:0.013,Oa:0.971,Miou:0.937,                                 time:1.6s
# Ep123: tra-> Loss:0.010,Oa:0.976,Miou:0.939, val-> Loss:0.021,Oa:0.933, Miou:0.862,time:3.1s
# Ep125: tra-> Loss:0.014,Oa:0.971,Miou:0.936,                                 time:1.6s
# Ep126: tra-> Loss:0.011,Oa:0.973,Miou:0.946,                                 time:1.5s
# Ep126: tra-> Loss:0.011,Oa:0.980,Miou:0.941, val-> Loss:0.016,Oa:0.934, Miou:0.878,time:3.0s
# Ep128: tra-> Loss:0.009,Oa:0.978,Miou:0.964,                                 time:1.6s
# Ep129: tra-> Loss:0.011,Oa:0.976,Miou:0.944,                                 time:1.5s
# Ep129: tra-> Loss:0.015,Oa:0.969,Miou:0.945, val-> Loss:0.014,Oa:0.936, Miou:0.895,time:3.0s
# Ep131: tra-> Loss:0.012,Oa:0.973,Miou:0.940,                                 time:1.6s
# Ep132: tra-> Loss:0.013,Oa:0.971,Miou:0.945,                                 time:1.7s
# Ep132: tra-> Loss:0.010,Oa:0.973,Miou:0.949, val-> Loss:0.014,Oa:0.936, Miou:0.894,time:3.1s
# Ep134: tra-> Loss:0.012,Oa:0.974,Miou:0.944,                                 time:1.5s
# Ep135: tra-> Loss:0.009,Oa:0.961,Miou:0.939,                                 time:1.5s
# Ep135: tra-> Loss:0.012,Oa:0.960,Miou:0.932, val-> Loss:0.015,Oa:0.937, Miou:0.886,time:3.2s
# Ep137: tra-> Loss:0.012,Oa:0.980,Miou:0.955,                                 time:1.6s
# Ep138: tra-> Loss:0.013,Oa:0.964,Miou:0.933,                                 time:1.6s
# Ep138: tra-> Loss:0.010,Oa:0.983,Miou:0.954, val-> Loss:0.015,Oa:0.935, Miou:0.886,time:3.2s
# Ep140: tra-> Loss:0.007,Oa:0.980,Miou:0.960,                                 time:1.6s
# Ep141: tra-> Loss:0.012,Oa:0.971,Miou:0.947,                                 time:1.5s
# Ep141: tra-> Loss:0.010,Oa:0.980,Miou:0.948, val-> Loss:0.018,Oa:0.933, Miou:0.871,time:2.9s
# Ep143: tra-> Loss:0.011,Oa:0.980,Miou:0.955,                                 time:1.5s
# Ep144: tra-> Loss:0.009,Oa:0.985,Miou:0.963,                                 time:1.4s
# Ep144: tra-> Loss:0.008,Oa:0.983,Miou:0.964, val-> Loss:0.014,Oa:0.935, Miou:0.892,time:3.1s
# Ep146: tra-> Loss:0.008,Oa:0.984,Miou:0.969,                                 time:1.6s
# Ep147: tra-> Loss:0.012,Oa:0.980,Miou:0.956,                                 time:1.5s
# Ep147: tra-> Loss:0.008,Oa:0.981,Miou:0.955, val-> Loss:0.016,Oa:0.934, Miou:0.880,time:3.0s
# Ep149: tra-> Loss:0.008,Oa:0.976,Miou:0.951,                                 time:1.6s
# Ep150: tra-> Loss:0.009,Oa:0.967,Miou:0.948,                                 time:1.6s
# Ep150: tra-> Loss:0.008,Oa:0.985,Miou:0.965, val-> Loss:0.015,Oa:0.937, Miou:0.900,time:3.2s
# Ep152: tra-> Loss:0.013,Oa:0.957,Miou:0.931,                                 time:1.5s
# Ep153: tra-> Loss:0.014,Oa:0.974,Miou:0.940,                                 time:1.6s
# Ep153: tra-> Loss:0.012,Oa:0.980,Miou:0.954, val-> Loss:0.015,Oa:0.934, Miou:0.888,time:3.2s
# Ep155: tra-> Loss:0.011,Oa:0.964,Miou:0.929,                                 time:1.7s
# Ep156: tra-> Loss:0.010,Oa:0.974,Miou:0.948,                                 time:1.5s
# Ep156: tra-> Loss:0.009,Oa:0.978,Miou:0.944, val-> Loss:0.017,Oa:0.934, Miou:0.877,time:3.1s
# Ep158: tra-> Loss:0.008,Oa:0.977,Miou:0.960,                                 time:1.5s
# Ep159: tra-> Loss:0.010,Oa:0.965,Miou:0.946,                                 time:1.5s
# Ep159: tra-> Loss:0.013,Oa:0.974,Miou:0.942, val-> Loss:0.014,Oa:0.936, Miou:0.900,time:3.1s
# Ep161: tra-> Loss:0.011,Oa:0.977,Miou:0.949,                                 time:1.5s
# Ep162: tra-> Loss:0.010,Oa:0.966,Miou:0.937,                                 time:1.6s
# Ep162: tra-> Loss:0.007,Oa:0.984,Miou:0.953, val-> Loss:0.015,Oa:0.935, Miou:0.887,time:3.0s
# Ep164: tra-> Loss:0.009,Oa:0.980,Miou:0.960,                                 time:1.6s
# Ep165: tra-> Loss:0.010,Oa:0.981,Miou:0.964,                                 time:1.5s
# Ep165: tra-> Loss:0.008,Oa:0.983,Miou:0.956, val-> Loss:0.014,Oa:0.936, Miou:0.893,time:3.1s
# Ep167: tra-> Loss:0.008,Oa:0.983,Miou:0.961,                                 time:1.5s
# Ep168: tra-> Loss:0.008,Oa:0.979,Miou:0.963,                                 time:1.5s
# Ep168: tra-> Loss:0.009,Oa:0.977,Miou:0.949, val-> Loss:0.015,Oa:0.935, Miou:0.885,time:3.0s
# Ep170: tra-> Loss:0.009,Oa:0.984,Miou:0.960,                                 time:1.5s
# Ep171: tra-> Loss:0.010,Oa:0.984,Miou:0.967,                                 time:1.6s
# Ep171: tra-> Loss:0.008,Oa:0.973,Miou:0.953, val-> Loss:0.014,Oa:0.935, Miou:0.890,time:3.0s
# Ep173: tra-> Loss:0.010,Oa:0.978,Miou:0.949,                                 time:1.5s
# Ep174: tra-> Loss:0.008,Oa:0.978,Miou:0.951,                                 time:1.5s
# Ep174: tra-> Loss:0.010,Oa:0.977,Miou:0.949, val-> Loss:0.015,Oa:0.937, Miou:0.892,time:3.0s
# Ep176: tra-> Loss:0.009,Oa:0.982,Miou:0.962,                                 time:1.5s
# Ep177: tra-> Loss:0.010,Oa:0.979,Miou:0.954,                                 time:1.5s
# Ep177: tra-> Loss:0.012,Oa:0.968,Miou:0.933, val-> Loss:0.015,Oa:0.936, Miou:0.889,time:3.0s
# Ep179: tra-> Loss:0.010,Oa:0.978,Miou:0.957,                                 time:1.5s
# Ep180: tra-> Loss:0.010,Oa:0.980,Miou:0.962,                                 time:1.5s
# Ep180: tra-> Loss:0.011,Oa:0.977,Miou:0.940, val-> Loss:0.018,Oa:0.934, Miou:0.875,time:3.1s
# Ep182: tra-> Loss:0.012,Oa:0.976,Miou:0.944,                                 time:1.5s
# Ep183: tra-> Loss:0.009,Oa:0.982,Miou:0.961,                                 time:1.6s
# Ep183: tra-> Loss:0.011,Oa:0.977,Miou:0.956, val-> Loss:0.015,Oa:0.934, Miou:0.886,time:3.0s
# Ep185: tra-> Loss:0.010,Oa:0.977,Miou:0.962,                                 time:1.5s
# Ep186: tra-> Loss:0.013,Oa:0.974,Miou:0.945,                                 time:1.5s
# Ep186: tra-> Loss:0.010,Oa:0.981,Miou:0.960, val-> Loss:0.016,Oa:0.936, Miou:0.883,time:3.0s
# Ep188: tra-> Loss:0.011,Oa:0.972,Miou:0.949,                                 time:1.5s
# Ep189: tra-> Loss:0.011,Oa:0.975,Miou:0.947,                                 time:1.5s
# Ep189: tra-> Loss:0.007,Oa:0.979,Miou:0.954, val-> Loss:0.014,Oa:0.936, Miou:0.892,time:3.0s
# Ep191: tra-> Loss:0.010,Oa:0.982,Miou:0.965,                                 time:1.5s
# Ep192: tra-> Loss:0.011,Oa:0.973,Miou:0.950,                                 time:1.5s
# Ep192: tra-> Loss:0.009,Oa:0.976,Miou:0.956, val-> Loss:0.015,Oa:0.935, Miou:0.890,time:3.0s
# Ep194: tra-> Loss:0.007,Oa:0.983,Miou:0.960,                                 time:1.5s
# Ep195: tra-> Loss:0.009,Oa:0.974,Miou:0.929,                                 time:1.5s
# Ep195: tra-> Loss:0.011,Oa:0.977,Miou:0.950, val-> Loss:0.015,Oa:0.936, Miou:0.890,time:3.0s
# Ep197: tra-> Loss:0.010,Oa:0.967,Miou:0.939,                                 time:1.5s
# Ep198: tra-> Loss:0.011,Oa:0.974,Miou:0.951,                                 time:1.6s
# Ep198: tra-> Loss:0.007,Oa:0.988,Miou:0.968, val-> Loss:0.016,Oa:0.936, Miou:0.895,time:3.0s
# Ep200: tra-> Loss:0.008,Oa:0.979,Miou:0.963,                                 time:1.5s
# Ep201: tra-> Loss:0.008,Oa:0.988,Miou:0.966,                                 time:1.5s
# Ep201: tra-> Loss:0.009,Oa:0.979,Miou:0.957, val-> Loss:0.015,Oa:0.935, Miou:0.885,time:3.0s
# Ep203: tra-> Loss:0.012,Oa:0.975,Miou:0.948,                                 time:1.5s
# Ep204: tra-> Loss:0.010,Oa:0.980,Miou:0.959,                                 time:1.5s
# Ep204: tra-> Loss:0.010,Oa:0.972,Miou:0.929, val-> Loss:0.015,Oa:0.937, Miou:0.893,time:3.1s
# Ep206: tra-> Loss:0.011,Oa:0.977,Miou:0.946,                                 time:1.5s
# Ep207: tra-> Loss:0.009,Oa:0.969,Miou:0.930,                                 time:1.5s
# Ep207: tra-> Loss:0.011,Oa:0.973,Miou:0.950, val-> Loss:0.015,Oa:0.937, Miou:0.889,time:3.0s
# Ep209: tra-> Loss:0.010,Oa:0.980,Miou:0.951,                                 time:1.6s
# Ep210: tra-> Loss:0.009,Oa:0.980,Miou:0.957,                                 time:1.6s
# Ep210: tra-> Loss:0.010,Oa:0.944,Miou:0.920, val-> Loss:0.014,Oa:0.936, Miou:0.893,time:3.0s
# Ep212: tra-> Loss:0.009,Oa:0.981,Miou:0.957,                                 time:1.7s
# Ep213: tra-> Loss:0.007,Oa:0.986,Miou:0.965,                                 time:1.5s
# Ep213: tra-> Loss:0.009,Oa:0.984,Miou:0.965, val-> Loss:0.014,Oa:0.936, Miou:0.894,time:3.0s
# Ep215: tra-> Loss:0.010,Oa:0.977,Miou:0.952,                                 time:1.5s
# Ep216: tra-> Loss:0.011,Oa:0.971,Miou:0.949,                                 time:1.5s
# Ep216: tra-> Loss:0.010,Oa:0.972,Miou:0.953, val-> Loss:0.015,Oa:0.936, Miou:0.887,time:3.0s
# Ep218: tra-> Loss:0.009,Oa:0.981,Miou:0.954,                                 time:1.4s
# Ep219: tra-> Loss:0.010,Oa:0.976,Miou:0.958,                                 time:1.5s
# Ep219: tra-> Loss:0.010,Oa:0.979,Miou:0.959, val-> Loss:0.015,Oa:0.936, Miou:0.890,time:3.0s
# Ep221: tra-> Loss:0.010,Oa:0.978,Miou:0.957,                                 time:1.5s
# Ep222: tra-> Loss:0.010,Oa:0.983,Miou:0.962,                                 time:1.6s
# Ep222: tra-> Loss:0.010,Oa:0.972,Miou:0.944, val-> Loss:0.018,Oa:0.922, Miou:0.879,time:3.2s
# Ep224: tra-> Loss:0.013,Oa:0.974,Miou:0.945,                                 time:1.6s
# Ep225: tra-> Loss:0.012,Oa:0.980,Miou:0.954,                                 time:1.7s
# Ep225: tra-> Loss:0.011,Oa:0.979,Miou:0.957, val-> Loss:0.015,Oa:0.936, Miou:0.892,time:3.0s
# Ep227: tra-> Loss:0.007,Oa:0.985,Miou:0.967,                                 time:1.5s
# Ep228: tra-> Loss:0.010,Oa:0.975,Miou:0.958,                                 time:1.5s
# Ep228: tra-> Loss:0.011,Oa:0.982,Miou:0.960, val-> Loss:0.015,Oa:0.937, Miou:0.892,time:3.2s
# Ep230: tra-> Loss:0.010,Oa:0.975,Miou:0.953,                                 time:1.5s
# Ep231: tra-> Loss:0.007,Oa:0.975,Miou:0.953,                                 time:1.7s
# Ep231: tra-> Loss:0.009,Oa:0.981,Miou:0.960, val-> Loss:0.015,Oa:0.936, Miou:0.891,time:3.1s
# Ep233: tra-> Loss:0.008,Oa:0.977,Miou:0.953,                                 time:1.6s
# Ep234: tra-> Loss:0.013,Oa:0.968,Miou:0.934,                                 time:1.5s
# Ep234: tra-> Loss:0.011,Oa:0.982,Miou:0.959, val-> Loss:0.016,Oa:0.936, Miou:0.887,time:3.0s
# Ep236: tra-> Loss:0.009,Oa:0.979,Miou:0.952,                                 time:1.5s
# Ep237: tra-> Loss:0.009,Oa:0.929,Miou:0.903,                                 time:1.5s
# Ep237: tra-> Loss:0.010,Oa:0.978,Miou:0.955, val-> Loss:0.015,Oa:0.936, Miou:0.892,time:3.1s
# Ep239: tra-> Loss:0.012,Oa:0.973,Miou:0.948,                                 time:1.4s
# Ep240: tra-> Loss:0.010,Oa:0.981,Miou:0.958,                                 time:1.5s
# Ep240: tra-> Loss:0.009,Oa:0.982,Miou:0.963, val-> Loss:0.015,Oa:0.936, Miou:0.893,time:3.0s
# Ep242: tra-> Loss:0.008,Oa:0.980,Miou:0.964,                                 time:1.5s
# Ep243: tra-> Loss:0.008,Oa:0.983,Miou:0.963,                                 time:1.6s
# Ep243: tra-> Loss:0.008,Oa:0.978,Miou:0.951, val-> Loss:0.015,Oa:0.936, Miou:0.890,time:3.0s
# Ep245: tra-> Loss:0.010,Oa:0.980,Miou:0.964,                                 time:1.5s
# Ep246: tra-> Loss:0.008,Oa:0.984,Miou:0.961,                                 time:1.6s
# Ep246: tra-> Loss:0.010,Oa:0.974,Miou:0.954, val-> Loss:0.015,Oa:0.936, Miou:0.889,time:3.0s
# Ep248: tra-> Loss:0.011,Oa:0.981,Miou:0.952,                                 time:1.4s
# Ep249: tra-> Loss:0.010,Oa:0.982,Miou:0.966,                                 time:1.5s
# Ep249: tra-> Loss:0.007,Oa:0.952,Miou:0.901, val-> Loss:0.018,Oa:0.926, Miou:0.881,time:2.9s
# Ep251: tra-> Loss:0.010,Oa:0.940,Miou:0.922,                                 time:1.6s
# Ep252: tra-> Loss:0.010,Oa:0.961,Miou:0.918,                                 time:1.5s
# Ep252: tra-> Loss:0.011,Oa:0.970,Miou:0.946, val-> Loss:0.017,Oa:0.934, Miou:0.888,time:3.1s
# Ep254: tra-> Loss:0.009,Oa:0.969,Miou:0.939,                                 time:1.4s
# Ep255: tra-> Loss:0.011,Oa:0.975,Miou:0.951,                                 time:1.6s
# Ep255: tra-> Loss:0.010,Oa:0.971,Miou:0.944, val-> Loss:0.016,Oa:0.936, Miou:0.889,time:3.0s
# Ep257: tra-> Loss:0.010,Oa:0.945,Miou:0.922,                                 time:1.5s
# Ep258: tra-> Loss:0.010,Oa:0.979,Miou:0.951,                                 time:1.4s
# Ep258: tra-> Loss:0.010,Oa:0.949,Miou:0.926, val-> Loss:0.015,Oa:0.937, Miou:0.892,time:3.0s
# Ep260: tra-> Loss:0.007,Oa:0.987,Miou:0.967,                                 time:1.6s
# Ep261: tra-> Loss:0.013,Oa:0.972,Miou:0.949,                                 time:1.6s
# Ep261: tra-> Loss:0.011,Oa:0.976,Miou:0.946, val-> Loss:0.016,Oa:0.936, Miou:0.889,time:3.1s
# Ep263: tra-> Loss:0.010,Oa:0.977,Miou:0.947,                                 time:1.6s
# Ep264: tra-> Loss:0.012,Oa:0.977,Miou:0.948,                                 time:1.4s
# Ep264: tra-> Loss:0.007,Oa:0.982,Miou:0.958, val-> Loss:0.016,Oa:0.937, Miou:0.890,time:3.1s
# Ep266: tra-> Loss:0.009,Oa:0.969,Miou:0.930,                                 time:1.4s
# Ep267: tra-> Loss:0.008,Oa:0.984,Miou:0.963,                                 time:1.7s
# Ep267: tra-> Loss:0.009,Oa:0.980,Miou:0.958, val-> Loss:0.016,Oa:0.936, Miou:0.889,time:3.1s
# Ep269: tra-> Loss:0.008,Oa:0.986,Miou:0.970,                                 time:1.5s
# Ep270: tra-> Loss:0.011,Oa:0.979,Miou:0.955,                                 time:1.6s
# Ep270: tra-> Loss:0.011,Oa:0.975,Miou:0.949, val-> Loss:0.016,Oa:0.936, Miou:0.892,time:3.1s
# Ep272: tra-> Loss:0.009,Oa:0.981,Miou:0.961,                                 time:1.5s
# Ep273: tra-> Loss:0.008,Oa:0.980,Miou:0.962,                                 time:1.6s
# Ep273: tra-> Loss:0.010,Oa:0.983,Miou:0.962, val-> Loss:0.016,Oa:0.936, Miou:0.891,time:3.1s
# Ep275: tra-> Loss:0.010,Oa:0.975,Miou:0.942,                                 time:1.5s
# Ep276: tra-> Loss:0.010,Oa:0.983,Miou:0.959,                                 time:1.5s
# Ep276: tra-> Loss:0.008,Oa:0.981,Miou:0.952, val-> Loss:0.016,Oa:0.936, Miou:0.890,time:3.1s
# Ep278: tra-> Loss:0.010,Oa:0.973,Miou:0.950,                                 time:1.5s
# Ep279: tra-> Loss:0.008,Oa:0.984,Miou:0.966,                                 time:1.6s
# Ep279: tra-> Loss:0.012,Oa:0.972,Miou:0.940, val-> Loss:0.016,Oa:0.936, Miou:0.889,time:3.1s
# Ep281: tra-> Loss:0.010,Oa:0.951,Miou:0.931,                                 time:1.5s
# Ep282: tra-> Loss:0.013,Oa:0.969,Miou:0.940,                                 time:1.6s
# Ep282: tra-> Loss:0.009,Oa:0.954,Miou:0.924, val-> Loss:0.016,Oa:0.932, Miou:0.888,time:3.0s
# Ep284: tra-> Loss:0.011,Oa:0.966,Miou:0.932,                                 time:1.5s
# Ep285: tra-> Loss:0.010,Oa:0.980,Miou:0.963,                                 time:1.5s
# Ep285: tra-> Loss:0.010,Oa:0.978,Miou:0.949, val-> Loss:0.016,Oa:0.934, Miou:0.891,time:3.1s
# Ep287: tra-> Loss:0.009,Oa:0.946,Miou:0.924,                                 time:1.5s
# Ep288: tra-> Loss:0.011,Oa:0.976,Miou:0.949,                                 time:1.6s
# Ep288: tra-> Loss:0.009,Oa:0.972,Miou:0.947, val-> Loss:0.016,Oa:0.936, Miou:0.892,time:3.1s
# Ep290: tra-> Loss:0.007,Oa:0.971,Miou:0.942,                                 time:1.5s
# Ep291: tra-> Loss:0.011,Oa:0.961,Miou:0.931,                                 time:1.6s
# Ep291: tra-> Loss:0.009,Oa:0.976,Miou:0.947, val-> Loss:0.016,Oa:0.936, Miou:0.892,time:3.1s
# Ep293: tra-> Loss:0.010,Oa:0.982,Miou:0.959,                                 time:1.4s
# Ep294: tra-> Loss:0.010,Oa:0.972,Miou:0.945,                                 time:1.6s
# Ep294: tra-> Loss:0.009,Oa:0.978,Miou:0.941, val-> Loss:0.016,Oa:0.936, Miou:0.892,time:3.2s
# Ep296: tra-> Loss:0.012,Oa:0.971,Miou:0.936,                                 time:1.5s
# Ep297: tra-> Loss:0.009,Oa:0.940,Miou:0.922,                                 time:1.5s
# Ep297: tra-> Loss:0.009,Oa:0.967,Miou:0.925, val-> Loss:0.016,Oa:0.934, Miou:0.891,time:3.0s
# Ep299: tra-> Loss:0.009,Oa:0.972,Miou:0.946,                                 time:1.5s
# Ep300: tra-> Loss:0.012,Oa:0.977,Miou:0.955,                                 time:1.5s

# %%
# model saving
# model_name = 'unet' 
model_name = 'u2net_dem_adj'
# net_name = 'deeplabv3plus'
## net_name = 'deeplabv3plus_mb2'
# path_save = f'model/trained/patch_{patch_size}/{model_name}_weights_1.pth'
path_save = f'model/trained/{model_name}_{patch_size}/{model_name}_weights_2.pth'
torch.save(model.state_dict(), path_save)     ## save weights of the trained model 
# # model.load_state_dict(torch.load(path_save, weights_only=True))  ## load the weights of the trained model
# # ## metrics saving
path_metrics = f'model/trained/{model_name}_{patch_size}/{model_name}_metrics_2.csv'    
# path_metrics = f'model/trained/patch_{patch_size}/{model_name}_metrics_1.csv'    
metrics_df = pd.DataFrame(metrics)
metrics_df.to_csv(path_metrics, index=False, sep=',')
